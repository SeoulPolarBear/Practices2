# %%
def func_AND(x1, x2):
#  w1, w2, threshold = 1, 2, 3
  w1, w2, threshold = 2, 2, 3
  if w1 * x1 + w2 * x2 <= threshold:
    return 0
  else:
    return 1
# print(func_AND(0,1))

def func_OR(x1,x2):
  w1, w2, threshold = 2, 2, 1
  w1, w2, threshold = 3, 2, 1
  if w1 * x1 + w2 * x2 <= threshold:
    return 0
  else:
    return 1

# print(func_OR(1,0))

def func_XOR(x1,x2):
  w1, w2, threshold = 2, 2, 1
  w3, w4, threshold2 = 2, 2, 3

  if w1 * x1 + w2 * x2 >= threshold and w3 * x1 + w4 * x2 <= threshold2:
    return 1
  else:
    return 0

# def fun_NOT(result):
#   return not(result)

# print(func_NAND(0,0))

#xor gate 검색
def func_XOR2(x1,x2):
  return func_OR(func_AND(x1,not x2),func_AND(not x1,x2))
print(func_XOR2(1,1))
# Out:
# 0
